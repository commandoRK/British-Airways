# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/customer_booking.csv",encoding="ISO-8859-1")

# %%
df
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49995               2      Internet  RoundTrip             27               6
# 49996               1      Internet  RoundTrip            111               6
# 49997               1      Internet  RoundTrip             24               6
# 49998               1      Internet  RoundTrip             15               6
# 49999               1      Internet  RoundTrip             19               6
#
# ...

# %%
pie=df['booking_complete'].groupby(df['sales_channel']).sum()

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(pie,labels=pie.index,autopct='%1.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8ba6bed4e0>,
# ...
#  [Text(-1.064193990658027, 0.2783723230627344, 'Internet'),
#   Text(1.0641939776264768, -0.2783723728812507, 'Mobile')],
#  [Text(-0.5804694494498328, 0.15183944894330964, '92%'),
#   Text(0.5804694423417145, -0.15183947611704585, '8%')])

# %%
pie1=df['booking_complete'].groupby(df['trip_type']).sum()

# %%
pie1
# Out:
# trip_type
# CircleTrip       5
# OneWay          20
# RoundTrip     7453
# Name: booking_complete, dtype: int64

# %%
flight=df['booking_complete'].groupby(df['flight_day']).sum()

# %%
flight.sort_values(ascending=True)
# Out:
# flight_day
# Sat     861
# Sun     927
# Fri     983
# Thu    1122
# Tue    1129
# Mon    1204
# Wed    1252
# Name: booking_complete, dtype: int64

# %%
plt.pie(flight, labels=flight.index, autopct='%1.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8ba6c4c6a0>,
# ...
#  [Text(1.0075264385046612, 0.4414640140646954, 'Fri'),
#   Text(0.2604506075875388, 1.0687214234810127, 'Mon'),
#   Text(-0.6467133364826311, 0.8898100136633119, 'Sat'),
#   Text(-1.0799649053372975, 0.20898756718953912, 'Sun'),
#   Text(-0.8624377279052389, -0.682789254078921, 'Thu'),
#   Text(0.04896882976576416, -1.0989094838572337, 'Tue'),
#   Text(0.9513159069817009, -0.5522662809945796, 'Wed')],
#  [Text(0.5495598755479969, 0.24079855312619744, '13%'),
#   Text(0.14206396777502114, 0.5829389582623705, '16%'),
#   Text(-0.352752728990526, 0.4853509165436246, '12%'),
#   Text(-0.5890717665476167, 0.11399321846702132, '12%'),
#   Text(-0.47042057885740296, -0.37243050222486596, '15%'),
#   Text(0.0267102707813259, -0.5994051730130365, '15%'),
#   Text(0.5188995856263823, -0.3012361532697707, '17%')])

# %%
df['booking_origin'].unique()
# Out:
# array(['New Zealand', 'India', 'United Kingdom', 'China', 'South Korea',
#        'Japan', 'Malaysia', 'Singapore', 'Switzerland', 'Germany',
#        'Indonesia', 'Czech Republic', 'Vietnam', 'Thailand', 'Spain',
#        'Romania', 'Ireland', 'Italy', 'Slovakia', 'United Arab Emirates',
#        'Tonga', 'Réunion', '(not set)', 'Saudi Arabia', 'Netherlands',
#        'Qatar', 'Hong Kong', 'Philippines', 'Sri Lanka', 'France',
#        'Croatia', 'United States', 'Laos', 'Hungary', 'Portugal',
#        'Cyprus', 'Australia', 'Cambodia', 'Poland', 'Belgium', 'Oman',
#        'Bangladesh', 'Kazakhstan', 'Brazil', 'Turkey', 'Kenya', 'Taiwan',
#        'Brunei', 'Chile', 'Bulgaria', 'Ukraine', 'Denmark', 'Colombia',
#        'Iran', 'Bahrain', 'Solomon Islands', 'Slovenia', 'Mauritius',
#        'Nepal', 'Russia', 'Kuwait', 'Mexico', 'Sweden', 'Austria',
#        'Lebanon', 'Jordan', 'Greece', 'Mongolia', 'Canada', 'Tanzania',
# ...

# %%
df['booking_complete'].groupby(df['flight_hour']).sum().sort_values(ascending=False)
# Out:
# flight_hour
# 9     508
# 13    503
# 14    489
# 6     488
# 8     484
# 12    460
# 5     431
# 4     430
# 7     423
# 10    415
# 11    407
# 3     393
# 2     389
# 15    376
# 16    297
# 1     285
# 0     182
# 17    167
# 23    103
# 18     85
# 22     54
# 21     45
# 19     39
# 20     25
# Name: booking_complete, dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49995               2      Internet  RoundTrip             27               6
# 49996               1      Internet  RoundTrip            111               6
# 49997               1      Internet  RoundTrip             24               6
# 49998               1      Internet  RoundTrip             15               6
# 49999               1      Internet  RoundTrip             19               6
#
# ...

# %%
df=df.drop({'route','booking_origin'},axis=1)

# %%
df
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49995               2      Internet  RoundTrip             27               6
# 49996               1      Internet  RoundTrip            111               6
# 49997               1      Internet  RoundTrip             24               6
# 49998               1      Internet  RoundTrip             15               6
# 49999               1      Internet  RoundTrip             19               6
#
# ...

# %%
df['flight_day'].unique()
# Out:
# array(['Sat', 'Wed', 'Thu', 'Mon', 'Sun', 'Tue', 'Fri'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
df['flight_day']=label.fit_transform(df['flight_day'])

# %%
df
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49995               2      Internet  RoundTrip             27               6
# 49996               1      Internet  RoundTrip            111               6
# 49997               1      Internet  RoundTrip             24               6
# 49998               1      Internet  RoundTrip             15               6
# 49999               1      Internet  RoundTrip             19               6
#
# ...

# %%
df['sales_channel']=label.fit_transform(df['sales_channel'])

# %%
df['trip_type']=label.fit_transform(df['trip_type'])

# %%
df
# Out:
#        num_passengers  sales_channel  trip_type  purchase_lead  \
# 0                   2              0          2            262
# 1                   1              0          2            112
# 2                   2              0          2            243
# 3                   1              0          2             96
# 4                   2              0          2             68
# ...               ...            ...        ...            ...
# 49995               2              0          2             27
# 49996               1              0          2            111
# 49997               1              0          2             24
# 49998               1              0          2             15
# 49999               1              0          2             19
#
#        length_of_stay  flight_hour  flight_day  wants_extra_baggage  \
# 0                  19            7           2                    1
# 1                  20            3           2                    0
# ...

# %%
df
# Out:
#        num_passengers  sales_channel  trip_type  purchase_lead  \
# 0                   2              0          2            262
# 1                   1              0          2            112
# 2                   2              0          2            243
# 3                   1              0          2             96
# 4                   2              0          2             68
# ...               ...            ...        ...            ...
# 49995               2              0          2             27
# 49996               1              0          2            111
# 49997               1              0          2             24
# 49998               1              0          2             15
# 49999               1              0          2             19
#
#        length_of_stay  flight_hour  flight_day  wants_extra_baggage  \
# 0                  19            7           2                    1
# 1                  20            3           2                    0
# ...

# %%
x=df.drop('booking_complete',axis=1)

# %%
y=df['booking_complete']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
ypred=model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.845

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[8357,  120],
#        [1430,   93]])

# %%
classification_report(ytest,ypred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.85      0.99      0.92      8477\n           1       0.44      0.06      0.11      1523\n\n    accuracy                           0.84     10000\n   macro avg       0.65      0.52      0.51     10000\nweighted avg       0.79      0.84      0.79     10000\n'
